# %%
# (Timing: ~ 1600 s)

import tarfile, re, time

keggdir = '..' # the folder of the downloaded KEGG database

# organism info
fhand = open(keggdir + '/kegg/genes/misc/taxonomy')

org2kingdom = dict()
org2species = dict()

for line in fhand:
    if line.startswith('# Eukaryotes'):
        kingdom = 'E'
    elif line.startswith('## Bacteria'):
        kingdom = 'B'
    elif line.startswith('## Archaea'):
        kingdom = 'A'
    elif not line.startswith('#'):
        org2kingdom[line.split('\t')[1]] = kingdom
        org2species[line.split('\t')[1]] = line.split('\t')[3].rstrip()


tar = tarfile.open(keggdir + '/kegg/ligand/reaction.tar.gz', 'r:gz')

# reaction-compound relationship
f_rc = tar.extractfile('reaction/reaction.lst')
rxn2cmpd = dict() # reaction to compound
# metabolites to be removed
rmMets1 = ['C00001','C00007','C00012','C00017','C00039','C00046','C00080']
rmMets2 = ['C00002','C00003','C00004','C00005','C00006','C00008','C00009',
           'C00010','C00013','C00016','C00019','C00020','C00021','C00035',
           'C00044','C00061','C00144','C00390','C00399','C01352','C01847']
for line in f_rc:
    r_id = line.decode().split(':')[0]
    cmpd_tmp = re.findall('[A-Z]\d{5}', line.decode().split(':')[1])
    cmpd_tmp1 = [ x for x in cmpd_tmp if x not in rmMets1]
    cmpd_tmp2 = [ x for x in cmpd_tmp1 if x not in rmMets2]
    if len(cmpd_tmp1) > 0:
        if len(cmpd_tmp2) > 0:
            cmpd = cmpd_tmp2
        else:
            cmpd = cmpd_tmp1
        rxn2cmpd[r_id] = cmpd
f_rc.close()

# reaction-EC relationship
f_rec = tar.extractfile('reaction/reaction')
rxn2ec = dict() # reaction to ec
flag = False # used for EC numbers in multiple lines
for line in f_rec:
    
    if line.decode().startswith('ENTRY'):
        r_id = re.findall('R\d{5}', line.decode())[0]
        rxn2ec[r_id] = []
    elif line.decode().startswith('ENZYME'):
        rxn2ec[r_id] += re.findall('\S+\.\S+\.\S+\.\S+', line.decode())
        if line.decode().endswith(' \n'):
            flag = True
    # for EC numbers in multiple lines
    if flag and line.decode().startswith(' '):
        rxn2ec[r_id] += re.findall('\S+\.\S+\.\S+\.\S+', line.decode())
        if line.decode().endswith(' \n'):
            flag = True
        else:
            flag = False

f_rec.close()
tar.close()


# KO- enzyme/reaction relationship
tar = tarfile.open(keggdir + '/kegg/genes/ko.tar.gz', 'r:gz')

# dict for KO-EC and KO-reaction
def generate_KOdict(file_name):
    KOdict = dict()
    f = tar.extractfile(file_name)
    for line in f:
        ko = line.decode().split('\t')[0][3:]
        ko_vals = line.decode().split('\t')[1].rstrip()[3:]
        if ko not in KOdict:
            KOdict[ko] = [ko_vals]
        else:
            KOdict[ko].append(ko_vals)
    f.close()
    return KOdict
ko2ec = generate_KOdict('ko/ko_enzyme.list') # KO to EC (not used in this project as there exists reaction to EC relationship)
ko2rxn = generate_KOdict('ko/ko_reaction.list') # KO to reaction


# write file for each organism based on KO-genes relationship

f_kg = tar.extractfile('ko/ko_genes.list')

org_list = []
time_start = time.time()

for line in f_kg:
    ko = line.decode().split('\t')[0][3:]
    if ko in ko2rxn: # only include genes with reactions
        gene_id = line.decode().split('\t')[1].rstrip()
        org_id = gene_id.split(':')[0]
        
        if org_id in org2kingdom:
            fout = open('output/' + org_id + '.txt', 'a')
            rxn_list = ko2rxn[ko]
            for rxn in rxn_list:
                ec_list = ';'.join(rxn2ec[rxn]) # (multiple ec numbers are grouped in one cell but could be splitted in future)
                cmpd_list = rxn2cmpd[rxn]
                for cmpd in cmpd_list:
                    line_to_write = gene_id+'\t'+org_id+'\t'+org2kingdom[org_id]+'\t'+ko+'\t'+rxn+'\t'+ec_list+'\t'+cmpd+'\n'
                    fout.write(line_to_write)

            fout.close()

            if org_id not in org_list:
                org_list += [org_id]
                if len(org_list)%100 == 0: 
                    time_end = time.time()
                    print('Done for', len(org_list), '/', len(org2kingdom), 'organisms', '[time cost:', round(time_end-time_start), 's]')

f_kg.close()
tar.close()
# Out:
# Done for 100 / 8120 organisms [time cost: 65 s]
# Done for 200 / 8120 organisms [time cost: 131 s]
# Done for 300 / 8120 organisms [time cost: 203 s]
# Done for 400 / 8120 organisms [time cost: 256 s]
# Done for 500 / 8120 organisms [time cost: 359 s]
# Done for 600 / 8120 organisms [time cost: 427 s]
# Done for 700 / 8120 organisms [time cost: 463 s]
# Done for 800 / 8120 organisms [time cost: 494 s]
# Done for 900 / 8120 organisms [time cost: 532 s]
# Done for 1000 / 8120 organisms [time cost: 574 s]
# Done for 1100 / 8120 organisms [time cost: 602 s]
# Done for 1200 / 8120 organisms [time cost: 637 s]
# Done for 1300 / 8120 organisms [time cost: 663 s]
# Done for 1400 / 8120 organisms [time cost: 683 s]
# Done for 1500 / 8120 organisms [time cost: 709 s]
# Done for 1600 / 8120 organisms [time cost: 742 s]
# Done for 1700 / 8120 organisms [time cost: 780 s]
# Done for 1800 / 8120 organisms [time cost: 818 s]
# Done for 1900 / 8120 organisms [time cost: 841 s]
# Done for 2000 / 8120 organisms [time cost: 853 s]
# Done for 2100 / 8120 organisms [time cost: 864 s]
# Done for 2200 / 8120 organisms [time cost: 875 s]
# Done for 2300 / 8120 organisms [time cost: 885 s]
# Done for 2400 / 8120 organisms [time cost: 894 s]
# Done for 2500 / 8120 organisms [time cost: 912 s]
# Done for 2600 / 8120 organisms [time cost: 930 s]
# Done for 2700 / 8120 organisms [time cost: 946 s]
# Done for 2800 / 8120 organisms [time cost: 959 s]
# Done for 2900 / 8120 organisms [time cost: 968 s]
# Done for 3000 / 8120 organisms [time cost: 975 s]
# Done for 3100 / 8120 organisms [time cost: 985 s]
# Done for 3200 / 8120 organisms [time cost: 997 s]
# Done for 3300 / 8120 organisms [time cost: 1001 s]
# Done for 3400 / 8120 organisms [time cost: 1022 s]
# Done for 3500 / 8120 organisms [time cost: 1041 s]
# Done for 3600 / 8120 organisms [time cost: 1058 s]
# Done for 3700 / 8120 organisms [time cost: 1076 s]
# Done for 3800 / 8120 organisms [time cost: 1097 s]
# Done for 3900 / 8120 organisms [time cost: 1113 s]
# Done for 4000 / 8120 organisms [time cost: 1128 s]
# Done for 4100 / 8120 organisms [time cost: 1143 s]
# Done for 4200 / 8120 organisms [time cost: 1160 s]
# Done for 4300 / 8120 organisms [time cost: 1177 s]
# Done for 4400 / 8120 organisms [time cost: 1190 s]
# Done for 4500 / 8120 organisms [time cost: 1203 s]
# Done for 4600 / 8120 organisms [time cost: 1218 s]
# Done for 4700 / 8120 organisms [time cost: 1227 s]
# Done for 4800 / 8120 organisms [time cost: 1236 s]
# Done for 4900 / 8120 organisms [time cost: 1246 s]
# Done for 5000 / 8120 organisms [time cost: 1256 s]
# Done for 5100 / 8120 organisms [time cost: 1270 s]
# Done for 5200 / 8120 organisms [time cost: 1284 s]
# Done for 5300 / 8120 organisms [time cost: 1298 s]
# Done for 5400 / 8120 organisms [time cost: 1305 s]
# Done for 5500 / 8120 organisms [time cost: 1308 s]
# Done for 5600 / 8120 organisms [time cost: 1319 s]
# Done for 5700 / 8120 organisms [time cost: 1340 s]
# Done for 5800 / 8120 organisms [time cost: 1350 s]
# Done for 5900 / 8120 organisms [time cost: 1369 s]
# Done for 6000 / 8120 organisms [time cost: 1393 s]
# Done for 6100 / 8120 organisms [time cost: 1410 s]
# Done for 6200 / 8120 organisms [time cost: 1424 s]
# Done for 6300 / 8120 organisms [time cost: 1438 s]
# Done for 6400 / 8120 organisms [time cost: 1459 s]
# Done for 6500 / 8120 organisms [time cost: 1471 s]
# Done for 6600 / 8120 organisms [time cost: 1483 s]
# Done for 6700 / 8120 organisms [time cost: 1498 s]
# Done for 6800 / 8120 organisms [time cost: 1509 s]
# Done for 6900 / 8120 organisms [time cost: 1514 s]
# Done for 7000 / 8120 organisms [time cost: 1527 s]
# Done for 7100 / 8120 organisms [time cost: 1537 s]
# Done for 7200 / 8120 organisms [time cost: 1549 s]
# Done for 7300 / 8120 organisms [time cost: 1564 s]
# Done for 7400 / 8120 organisms [time cost: 1579 s]
# Done for 7500 / 8120 organisms [time cost: 1593 s]
# Done for 7600 / 8120 organisms [time cost: 1604 s]
# Done for 7700 / 8120 organisms [time cost: 1614 s]
# Done for 7800 / 8120 organisms [time cost: 1623 s]
# Done for 7900 / 8120 organisms [time cost: 1635 s]
# Done for 8000 / 8120 organisms [time cost: 1649 s]
